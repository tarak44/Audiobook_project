# %%
import numpy as np
import tensorflow as tf
from sklearn import preprocessing

# Load dataset
raw_csv_data = np.loadtxt('Audiobooks_data.csv', delimiter=',')

# Inputs = all columns except first (ID) and last (target)
unscaled_inputs_all = raw_csv_data[:, 1:-1]
targets_all = raw_csv_data[:, -1]

# Balance the dataset
num_one_targets = int(np.sum(targets_all))
zero_targets_counter = 0
indices_to_remove = []
for i in range(targets_all.shape[0]):
    if targets_all[i] == 0:
        zero_targets_counter += 1
    if zero_targets_counter > num_one_targets:
        indices_to_remove.append(i)

unscaled_inputs = np.delete(unscaled_inputs_all, indices_to_remove, axis=0)
unscaled_targets = np.delete(targets_all, indices_to_remove, axis=0)

# Scale inputs only
scaled_inputs = preprocessing.scale(unscaled_inputs)
scaled_targets = unscaled_targets  # keep as 0/1

# Shuffle
shuffled_indices = np.arange(scaled_inputs.shape[0])
np.random.shuffle(shuffled_indices)
shuffled_inputs = scaled_inputs[shuffled_indices]
shuffled_targets = scaled_targets[shuffled_indices]

# Train/Val/Test split
samples_count = shuffled_inputs.shape[0]
train_samples_count = int(0.8 * samples_count)
validation_samples_count = int(0.1 * samples_count)
test_samples_count = samples_count - train_samples_count - validation_samples_count

train_inputs = shuffled_inputs[:train_samples_count]
train_targets = shuffled_targets[:train_samples_count]
validation_inputs = shuffled_inputs[train_samples_count:train_samples_count+validation_samples_count]
validation_targets = shuffled_targets[train_samples_count:train_samples_count+validation_samples_count]
test_inputs = shuffled_inputs[train_samples_count+validation_samples_count:]
test_targets = shuffled_targets[train_samples_count+validation_samples_count:]

# Save
np.savez('Audiobooks_train', inputs=train_inputs, targets=train_targets)
np.savez('Audiobooks_validation', inputs=validation_inputs, targets=validation_targets)
np.savez('Audiobooks_test', inputs=test_inputs, targets=test_targets)

# Load properly
npz = np.load('Audiobooks_train.npz')
train_inputs1, train_targets1 = npz['inputs'].astype(float), npz['targets'].astype(int)

npz = np.load('Audiobooks_validation.npz')
validation_inputs1, validation_targets1 = npz['inputs'].astype(float), npz['targets'].astype(int)

npz = np.load('Audiobooks_test.npz')
test_inputs1, test_targets1 = npz['inputs'].astype(float), npz['targets'].astype(int)

# Model
input_size = train_inputs1.shape[1]
output_size = 2
hidden_layer_size = 100

model = tf.keras.Sequential([
    tf.keras.layers.Dense(hidden_layer_size, activation='relu', input_shape=(input_size,)),
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(output_size, activation='softmax'),
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train
model.fit(train_inputs1, train_targets1, 
          validation_data=(validation_inputs1, validation_targets1),
          batch_size=100, epochs=50, verbose=2)
# Out:
# Epoch 1/50
# 36/36 - 1s - loss: 0.5959 - accuracy: 0.6812 - 1s/epoch - 29ms/step
# Epoch 2/50
# 36/36 - 0s - loss: 0.4009 - accuracy: 0.8371 - 126ms/epoch - 4ms/step
# Epoch 3/50
# 36/36 - 0s - loss: 0.3531 - accuracy: 0.8620 - 130ms/epoch - 4ms/step
# Epoch 4/50
# 36/36 - 0s - loss: 0.3323 - accuracy: 0.8706 - 131ms/epoch - 4ms/step
# Epoch 5/50
# 36/36 - 0s - loss: 0.3190 - accuracy: 0.8790 - 130ms/epoch - 4ms/step
# Epoch 6/50
# 36/36 - 0s - loss: 0.3082 - accuracy: 0.8815 - 142ms/epoch - 4ms/step
# Epoch 7/50
# 36/36 - 0s - loss: 0.2938 - accuracy: 0.8871 - 175ms/epoch - 5ms/step
# Epoch 8/50
# 36/36 - 0s - loss: 0.2881 - accuracy: 0.8933 - 193ms/epoch - 5ms/step
# Epoch 9/50
# 36/36 - 0s - loss: 0.2798 - accuracy: 0.8955 - 167ms/epoch - 5ms/step
# Epoch 10/50
# 36/36 - 0s - loss: 0.2714 - accuracy: 0.8989 - 187ms/epoch - 5ms/step
# Epoch 11/50
# 36/36 - 0s - loss: 0.2657 - accuracy: 0.9036 - 183ms/epoch - 5ms/step
# Epoch 12/50
# 36/36 - 0s - loss: 0.2669 - accuracy: 0.9042 - 171ms/epoch - 5ms/step
# Epoch 13/50
# 36/36 - 0s - loss: 0.2710 - accuracy: 0.8969 - 204ms/epoch - 6ms/step
# Epoch 14/50
# 36/36 - 0s - loss: 0.2565 - accuracy: 0.9050 - 183ms/epoch - 5ms/step
# Epoch 15/50
# 36/36 - 0s - loss: 0.2524 - accuracy: 0.9081 - 178ms/epoch - 5ms/step
# Epoch 16/50
# 36/36 - 0s - loss: 0.2541 - accuracy: 0.9100 - 170ms/epoch - 5ms/step
# Epoch 17/50
# 36/36 - 0s - loss: 0.2493 - accuracy: 0.9106 - 172ms/epoch - 5ms/step
# Epoch 18/50
# 36/36 - 0s - loss: 0.2445 - accuracy: 0.9125 - 194ms/epoch - 5ms/step
# Epoch 19/50
# 36/36 - 0s - loss: 0.2432 - accuracy: 0.9125 - 183ms/epoch - 5ms/step
# Epoch 20/50
# 36/36 - 0s - loss: 0.2440 - accuracy: 0.9109 - 180ms/epoch - 5ms/step
# Epoch 21/50
# 36/36 - 0s - loss: 0.2425 - accuracy: 0.9117 - 174ms/epoch - 5ms/step
# Epoch 22/50
# 36/36 - 0s - loss: 0.2415 - accuracy: 0.9125 - 173ms/epoch - 5ms/step
# Epoch 23/50
# 36/36 - 0s - loss: 0.2375 - accuracy: 0.9128 - 178ms/epoch - 5ms/step
# Epoch 24/50
# 36/36 - 0s - loss: 0.2380 - accuracy: 0.9123 - 177ms/epoch - 5ms/step
# Epoch 25/50
# 36/36 - 0s - loss: 0.2424 - accuracy: 0.9089 - 176ms/epoch - 5ms/step
# Epoch 26/50
# 36/36 - 0s - loss: 0.2391 - accuracy: 0.9084 - 173ms/epoch - 5ms/step
# Epoch 27/50
# 36/36 - 0s - loss: 0.2314 - accuracy: 0.9153 - 184ms/epoch - 5ms/step
# Epoch 28/50
# 36/36 - 0s - loss: 0.2417 - accuracy: 0.9109 - 176ms/epoch - 5ms/step
# Epoch 29/50
# 36/36 - 0s - loss: 0.2373 - accuracy: 0.9114 - 180ms/epoch - 5ms/step
# Epoch 30/50
# 36/36 - 0s - loss: 0.2331 - accuracy: 0.9125 - 176ms/epoch - 5ms/step
# Epoch 31/50
# 36/36 - 0s - loss: 0.2312 - accuracy: 0.9153 - 180ms/epoch - 5ms/step
# Epoch 32/50
# 36/36 - 0s - loss: 0.2291 - accuracy: 0.9159 - 182ms/epoch - 5ms/step
# Epoch 33/50
# 36/36 - 0s - loss: 0.2321 - accuracy: 0.9139 - 191ms/epoch - 5ms/step
# Epoch 34/50
# 36/36 - 0s - loss: 0.2318 - accuracy: 0.9134 - 178ms/epoch - 5ms/step
# Epoch 35/50
# 36/36 - 0s - loss: 0.2310 - accuracy: 0.9142 - 195ms/epoch - 5ms/step
# Epoch 36/50
# 36/36 - 0s - loss: 0.2294 - accuracy: 0.9162 - 176ms/epoch - 5ms/step
# Epoch 37/50
# 36/36 - 0s - loss: 0.2284 - accuracy: 0.9173 - 176ms/epoch - 5ms/step
# Epoch 38/50
# 36/36 - 0s - loss: 0.2250 - accuracy: 0.9159 - 175ms/epoch - 5ms/step
# Epoch 39/50
# 36/36 - 0s - loss: 0.2259 - accuracy: 0.9156 - 177ms/epoch - 5ms/step
# Epoch 40/50
# 36/36 - 0s - loss: 0.2295 - accuracy: 0.9142 - 181ms/epoch - 5ms/step
# Epoch 41/50
# 36/36 - 0s - loss: 0.2302 - accuracy: 0.9153 - 177ms/epoch - 5ms/step
# Epoch 42/50
# 36/36 - 0s - loss: 0.2273 - accuracy: 0.9162 - 173ms/epoch - 5ms/step
# Epoch 43/50
# 36/36 - 0s - loss: 0.2251 - accuracy: 0.9142 - 167ms/epoch - 5ms/step
# Epoch 44/50
# 36/36 - 0s - loss: 0.2226 - accuracy: 0.9193 - 176ms/epoch - 5ms/step
# Epoch 45/50
# 36/36 - 0s - loss: 0.2232 - accuracy: 0.9187 - 178ms/epoch - 5ms/step
# Epoch 46/50
# 36/36 - 0s - loss: 0.2237 - accuracy: 0.9165 - 176ms/epoch - 5ms/step
# Epoch 47/50
# 36/36 - 0s - loss: 0.2268 - accuracy: 0.9137 - 176ms/epoch - 5ms/step
# Epoch 48/50
# 36/36 - 0s - loss: 0.2265 - accuracy: 0.9125 - 179ms/epoch - 5ms/step
# Epoch 49/50
# 36/36 - 0s - loss: 0.2235 - accuracy: 0.9173 - 191ms/epoch - 5ms/step
# Epoch 50/50
# 36/36 - 0s - loss: 0.2207 - accuracy: 0.9181 - 185ms/epoch - 5ms/step

# %%
model.fit
